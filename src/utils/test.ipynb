# %%
import os
import pandas as pd

concat = pd.read_csv('../../data/fourdbs_concat/fourdbs_input_species.csv')
concat
# Out:
#                     species_name  \
# 0       saccharomyces_cerevisiae
# 1             fusarium_oxysporum
# 2               candida_albicans
# 3        cryptococcus_neoformans
# 4     saccharomyces_kudriavzevii
# ...                          ...
# 2122         acarospora_strigata
# 2123              absidia_repens
# 2124             absidia_padenii
# 2125            absidia_caerulea
# 2126         abortiporus_biennis
#
#                                        genome_file_name  \
# 0                  saccharomyces_cerevisiae_genomic.fna
# 1                        fusarium_oxysporum_genomic.fna
# 2                          candida_albicans_genomic.fna
# 3                   cryptococcus_neoformans_genomic.fna
# 4                saccharomyces_kudriavzevii_genomic.fna
# ...                                                 ...
# 2122         acarospora_strigata_cbs_132363_genomic.fna
# 2123          absidia_repens_nrrl_1336_v1_0_genomic.fna
# ...

# %%
gffs = os.listdir('../../data/fourdbs_concat_old' + "/gff/")
genomes = os.listdir('../../data/fourdbs_concat_old' + "/genomes/")
proteomes = os.listdir('../../data/fourdbs_concat_old' + "/proteomes/")

for gff_f in gffs:
    if gff_f not in concat['gff_file_name']:
        print(gff_f)
        print(f'../../data/fourdbs_concat_old/gff/{gff_f}')
# Out:
# mycena_rosella_cbhhk067_v1_0.gff
# ../../data/fourdbs_concat_old/gff/mycena_rosella_cbhhk067_v1_0.gff
# coccidioides_immitis.gff
# ../../data/fourdbs_concat_old/gff/coccidioides_immitis.gff
# nematocida_ausubeli.gff
# ../../data/fourdbs_concat_old/gff/nematocida_ausubeli.gff
# aspergillus_nishimurae_ifm_54133_v1_0.gff
# ../../data/fourdbs_concat_old/gff/aspergillus_nishimurae_ifm_54133_v1_0.gff
# xylographa_opegraphella.gff
# ../../data/fourdbs_concat_old/gff/xylographa_opegraphella.gff
# syncephalastrum_racemosum_str_nrrl_2496.gff
# ../../data/fourdbs_concat_old/gff/syncephalastrum_racemosum_str_nrrl_2496.gff
# talaromyces_proteolyticus_pmi_201_v1_0.gff
# ../../data/fourdbs_concat_old/gff/talaromyces_proteolyticus_pmi_201_v1_0.gff
# russula_rugulosa_bpl654_v1_0.gff
# ../../data/fourdbs_concat_old/gff/russula_rugulosa_bpl654_v1_0.gff
# lindgomyces_ingoldianus.gff
# ../../data/fourdbs_concat_old/gff/lindgomyces_ingoldianus.gff
# aspergillus_fructiculosus_v1_0.gff
# ...

# %%
'mycena_rosella_cbhhk067_v1_0.gff' in concat['gff_file_name'].tolist()
# Out:
# True
