# %%
import os
import re
import yaml
import argparse
import pandas as pd
from Bio import SeqIO

def parse_arguments() -> argparse.Namespace:
    parser = argparse.ArgumentParser()

    parser.add_argument(
        '--config',
        type=argparse.FileType(mode='r'),
        default='config.yaml', 
        help='The config file to use. Must be placed in the root folder.',
    )

    args, unknown = parser.parse_known_args()
    if args.config:
        data = yaml.load(args.config, Loader=yaml.FullLoader)
        arg_dict = args.__dict__

        for key, value in data.items():
            arg_dict[key] = value

    return args

args = parse_arguments()

acc_to_name = dict()

ref_species_path = os.path.join('inputs/reference/',
                                [f for f in os.listdir('inputs/reference/') if f.startswith(args.species) and not f.endswith('.dmnd')][0])

reference_records = SeqIO.parse(ref_species_path, 'fasta')

gene_name_re = r'\[gene=(.*?)\]'

for record in reference_records:
    gene_name_match = re.search(gene_name_re, record.description)

    if gene_name_match:
        gene_name = gene_name_match.group(1)
        prot_id = record.id

        acc_to_name[prot_id] = gene_name


num_files = len(os.listdir('outputs'))

ortho = pd.read_csv("Orthogroups.tsv", sep='\t').set_index('Orthogroup')

# %%
acc_to_name
# Out:
# {'NP_009673.1': 'LYS2',
#  'NP_010290.3': 'TRP1',
#  'NP_010851.1': 'CAN1',
#  'NP_010893.3': 'URA3',
#  'NP_012965.3': 'GAP1',
#  'NP_015387.1': 'FCY1'}

# %%
ortho['aspergillus_burnettii']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/allegro/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'aspergillus_burnettii'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ortho['aspergillus_burnettii']
#
# File ~/miniconda3/envs/allegro/lib/python3.10/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/miniconda3/envs/allegro/lib/python3.10/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'aspergillus_burnettii'

# %%
def find_cols_with_x_not_found(df, x):
    return df.columns[df.eq('Not found').sum() == x].tolist()

d = dict()
missing_in = dict()

d = {key: [] for key in acc_to_name}
missing_in = {key: [] for key in acc_to_name}

# %%
not_found_counts = ortho.eq('Not found').sum()

# %%
not_found_counts
# Out:
# asterophora_parasitica                  3
# lentinula_novae_zelandiae               2
# echinodontium_tinctorium_aho_80_v1_0    3
# pyrenophora_tritici_repentis            2
# aspergillus_albertensis_v1_0            1
#                                        ..
# hericium_coralloides_fp_101451_v1_0     3
# aspergillus_nutans_cbs_121_56_v1_0      1
# clitocybe_gibba_ijfm_a808_v1_0          2
# penicillium_egyptiacum                  1
# monilinia_fructigena_str_mfrg269        1
# Length: 2310, dtype: int64

# %%
for species in [e for e in ortho.columns.tolist()]:
    df = pd.read_csv(f'outputs/reciprocal/{species}.tsv', sep='\t', names=['scer_gene', 'ortho', 'identity', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i'])

    for gene, l in d.items():
        if ortho[species][gene] != 'Not found' and gene in df['scer_gene'].values:
            d[gene].append(df[df['scer_gene'] == gene]['identity'].values[0])
        else:
            missing_in[gene].append(species)
            
total_missing = 0
for gene, missing_in_species in missing_in.items():
    length = len(missing_in_species)
    print(f'Gene {gene} {acc_to_name[gene]} is missing its ortholog in {length} species')
    total_missing += length

print(f'Total missing orthologs {total_missing}')
# Out:
# Gene NP_009673.1 LYS2 is missing its ortholog in 46 species
# Gene NP_010290.3 TRP1 is missing its ortholog in 2128 species
# Gene NP_010851.1 CAN1 is missing its ortholog in 1175 species
# Gene NP_010893.3 URA3 is missing its ortholog in 72 species
# Gene NP_012965.3 GAP1 is missing its ortholog in 570 species
# Gene NP_015387.1 FCY1 is missing its ortholog in 838 species
# Total missing orthologs 4829

# %% [markdown]
# ## Mark orthologs with low (< 30%) identity as "Not found"

# %%
ortho_high_identity = ortho.copy(deep=True)

for species in ortho.columns.tolist():
    df = pd.read_csv(f'outputs/reciprocal/{species}.tsv', sep='\t')
    low_identities = df[df['identity'].astype(int) < 29]['query'].tolist()
    ortho_high_identity.loc[ortho_high_identity.index.isin(low_identities), species] = 'Not found'

ortho_high_identity
# Out:
#             asterophora_parasitica lentinula_novae_zelandiae  \
# Orthogroup
# NP_009673.1           KAG5643080.1              KAJ3864078.1
# NP_010290.3              Not found                 Not found
# NP_010851.1              Not found                 Not found
# NP_010893.3           KAG5648969.1              KAJ3869448.1
# NP_012965.3           KAG5641088.1              KAJ3865198.1
# NP_015387.1              Not found              KAJ3862919.1
#
#                         echinodontium_tinctorium_aho_80_v1_0  \
# Orthogroup
# NP_009673.1  fgenesh1_kg.17_#_321_#_TRINITY_DN20072_c0_g1_i2
# NP_010290.3                                        Not found
# NP_010851.1                                        Not found
# NP_010893.3  fgenesh1_kg.20_#_209_#_TRINITY_DN19773_c0_g2_i1
# NP_012965.3                                        Not found
# NP_015387.1                                    CE133509_1510
#
#             pyrenophora_tritici_repentis  \
# Orthogroup
# NP_009673.1               XP_001935976.1
# NP_010290.3                    Not found
# NP_010851.1               XP_001932482.1
# NP_010893.3               XP_001940698.2
# NP_012965.3               XP_001933206.1
# NP_015387.1                    Not found
#
#                                aspergillus_albertensis_v1_0  \
# Orthogroup
# NP_009673.1                                    CE60723_2593
# NP_010290.3                                       Not found
# NP_010851.1                                    CE53660_1995
# NP_010893.3   fgenesh1_kg.18_#_167_#_TRINITY_DN323_c0_g1_i1
# NP_012965.3  fgenesh1_kg.49_#_110_#_TRINITY_DN4837_c0_g1_i3
# NP_015387.1                                      CE3665_142
#
#                     trichoderma_cremeoides_cbs_131486_v1_0  \
# Orthogroup
# NP_009673.1    fgenesh1_kg.1_#_304_#_TRINITY_DN64_c3_g2_i1
# NP_010290.3                                      Not found
# NP_010851.1  fgenesh1_kg.8_#_666_#_TRINITY_DN5445_c0_g2_i1
# NP_010893.3                                  CE62015_19051
# NP_012965.3                                  CE137514_5108
# NP_015387.1                                      Not found
#
#             talaromyces_stipitatus  \
# Orthogroup
# NP_009673.1         XP_002480033.1
# NP_010290.3              Not found
# NP_010851.1              Not found
# NP_010893.3         XP_002478821.1
# NP_012965.3         XP_002478659.1
# NP_015387.1         XP_002484082.1
#
#                        aspergillus_iizukae_cbs_541_69_v1_0  \
# Orthogroup
# NP_009673.1                                  CE153030_3531
# NP_010290.3                                      Not found
# NP_010851.1                                  CE228629_2288
# NP_010893.3  fgenesh1_kg.3_#_607_#_TRINITY_DN1531_c0_g2_i1
# NP_012965.3                             fgenesh1_pm.2_#_44
# NP_015387.1                                   CE278982_806
#
#             microthyrium_microscopicum pseudovirgaria_hyperparasitica  ...  \
# Orthogroup                                                             ...
# NP_009673.1               KAF2666154.1                 XP_033596428.1  ...
# NP_010290.3                  Not found                      Not found  ...
# NP_010851.1                  Not found                 XP_033604410.1  ...
# NP_010893.3               KAF2665404.1                 XP_033599265.1  ...
# NP_012965.3               KAF2671377.1                 XP_033599698.1  ...
# NP_015387.1               KAF2674182.1                 XP_033596706.1  ...
#
#                          flavomyces_fulophazii_dse8309_v1_0  \
# Orthogroup
# NP_009673.1   fgenesh1_kg.93_#_58_#_TRINITY_DN4977_c3_g2_i2
# NP_010290.3                                       Not found
# NP_010851.1  fgenesh1_kg.35_#_251_#_TRINITY_DN5543_c0_g1_i4
# NP_010893.3                                  e_gw1.15.312.1
# NP_012965.3    fgenesh1_kg.34_#_99_#_TRINITY_DN242_c0_g1_i4
# NP_015387.1   fgenesh1_kg.7_#_472_#_TRINITY_DN6029_c0_g1_i2
#
#             trichoderma_sinense_daom_230004_v1_0 fusarium_tjaetaba  \
# Orthogroup
# NP_009673.1                       CE149144_25113    XP_037212304.1
# NP_010290.3                            Not found         Not found
# NP_010851.1                         CE43583_1555         Not found
# NP_010893.3                        CE282625_9301    XP_037207718.1
# NP_012965.3                        CE307390_2479    XP_037203345.1
# NP_015387.1                            Not found         Not found
#
#             galerina_marginata_cbs_339_88 neocallimastix_constans_g3_v1_0  \
# Orthogroup
# NP_009673.1                      KDR72580                  e_gw1.13.106.1
# NP_010290.3                     Not found                       Not found
# NP_010851.1                      KDR69137                       Not found
# NP_010893.3                      KDR83643   estExt_Genewise1Plus.C_400096
# NP_012965.3                      KDR79443                       Not found
# NP_015387.1                      KDR73199                       Not found
#
#                         hericium_coralloides_fp_101451_v1_0  \
# Orthogroup
# NP_009673.1                                  CE352478_12376
# NP_010290.3                                       Not found
# NP_010851.1                                       Not found
# NP_010893.3  fgenesh1_kg.19_#_334_#_TRINITY_DN4771_c0_g5_i1
# NP_012965.3                                       Not found
# NP_015387.1                                    CE16674_1415
#
#                          aspergillus_nutans_cbs_121_56_v1_0  \
# Orthogroup
# NP_009673.1  fgenesh1_kg.8_#_608_#_TRINITY_DN11024_c0_g1_i7
# NP_010290.3                                       Not found
# NP_010851.1                                   CE166465_8796
# NP_010893.3                                     CE85965_321
# NP_012965.3   fgenesh1_kg.69_#_19_#_TRINITY_DN9768_c0_g1_i1
# NP_015387.1                                       gm1.281_g
#
#             clitocybe_gibba_ijfm_a808_v1_0 penicillium_egyptiacum  \
# Orthogroup
# NP_009673.1            fgenesh1_pm.31_#_47           CAG8904822.1
# NP_010290.3                      Not found              Not found
# NP_010851.1                      Not found           CAG8907289.1
# NP_010893.3                  e_gw1.2.862.1           CAG8889705.1
# NP_012965.3                  e_gw1.121.4.1           CAG8903919.1
# NP_015387.1                     gm1.2445_g           CAG8893190.1
#
#             monilinia_fructigena_str_mfrg269
# Orthogroup
# NP_009673.1                         RAL64359
# NP_010290.3                        Not found
# NP_010851.1                         RAL64634
# NP_010893.3                         RAL62221
# NP_012965.3                         RAL59412
# NP_015387.1                         RAL66932
#
# [6 rows x 2310 columns]

# %% [markdown]
# ## Remove species with all missing orthologs

# %%
cols_with_all_not_found = find_cols_with_x_not_found(ortho_high_identity, len(ortho_high_identity))
len(cols_with_all_not_found)
# Out:
# 40

# %%
ortho_high_identity.drop(cols_with_all_not_found, axis=1, inplace=True)

ortho_high_identity
# Out:
#             asterophora_parasitica lentinula_novae_zelandiae  \
# Orthogroup
# NP_009673.1           KAG5643080.1              KAJ3864078.1
# NP_010290.3              Not found                 Not found
# NP_010851.1              Not found                 Not found
# NP_010893.3           KAG5648969.1              KAJ3869448.1
# NP_012965.3           KAG5641088.1              KAJ3865198.1
# NP_015387.1              Not found              KAJ3862919.1
#
#                         echinodontium_tinctorium_aho_80_v1_0  \
# Orthogroup
# NP_009673.1  fgenesh1_kg.17_#_321_#_TRINITY_DN20072_c0_g1_i2
# NP_010290.3                                        Not found
# NP_010851.1                                        Not found
# NP_010893.3  fgenesh1_kg.20_#_209_#_TRINITY_DN19773_c0_g2_i1
# NP_012965.3                                        Not found
# NP_015387.1                                    CE133509_1510
#
#             pyrenophora_tritici_repentis  \
# Orthogroup
# NP_009673.1               XP_001935976.1
# NP_010290.3                    Not found
# NP_010851.1               XP_001932482.1
# NP_010893.3               XP_001940698.2
# NP_012965.3               XP_001933206.1
# NP_015387.1                    Not found
#
#                                aspergillus_albertensis_v1_0  \
# Orthogroup
# NP_009673.1                                    CE60723_2593
# NP_010290.3                                       Not found
# NP_010851.1                                    CE53660_1995
# NP_010893.3   fgenesh1_kg.18_#_167_#_TRINITY_DN323_c0_g1_i1
# NP_012965.3  fgenesh1_kg.49_#_110_#_TRINITY_DN4837_c0_g1_i3
# NP_015387.1                                      CE3665_142
#
#                     trichoderma_cremeoides_cbs_131486_v1_0  \
# Orthogroup
# NP_009673.1    fgenesh1_kg.1_#_304_#_TRINITY_DN64_c3_g2_i1
# NP_010290.3                                      Not found
# NP_010851.1  fgenesh1_kg.8_#_666_#_TRINITY_DN5445_c0_g2_i1
# NP_010893.3                                  CE62015_19051
# NP_012965.3                                  CE137514_5108
# NP_015387.1                                      Not found
#
#             talaromyces_stipitatus  \
# Orthogroup
# NP_009673.1         XP_002480033.1
# NP_010290.3              Not found
# NP_010851.1              Not found
# NP_010893.3         XP_002478821.1
# NP_012965.3         XP_002478659.1
# NP_015387.1         XP_002484082.1
#
#                        aspergillus_iizukae_cbs_541_69_v1_0  \
# Orthogroup
# NP_009673.1                                  CE153030_3531
# NP_010290.3                                      Not found
# NP_010851.1                                  CE228629_2288
# NP_010893.3  fgenesh1_kg.3_#_607_#_TRINITY_DN1531_c0_g2_i1
# NP_012965.3                             fgenesh1_pm.2_#_44
# NP_015387.1                                   CE278982_806
#
#             microthyrium_microscopicum pseudovirgaria_hyperparasitica  ...  \
# Orthogroup                                                             ...
# NP_009673.1               KAF2666154.1                 XP_033596428.1  ...
# NP_010290.3                  Not found                      Not found  ...
# NP_010851.1                  Not found                 XP_033604410.1  ...
# NP_010893.3               KAF2665404.1                 XP_033599265.1  ...
# NP_012965.3               KAF2671377.1                 XP_033599698.1  ...
# NP_015387.1               KAF2674182.1                 XP_033596706.1  ...
#
#                          flavomyces_fulophazii_dse8309_v1_0  \
# Orthogroup
# NP_009673.1   fgenesh1_kg.93_#_58_#_TRINITY_DN4977_c3_g2_i2
# NP_010290.3                                       Not found
# NP_010851.1  fgenesh1_kg.35_#_251_#_TRINITY_DN5543_c0_g1_i4
# NP_010893.3                                  e_gw1.15.312.1
# NP_012965.3    fgenesh1_kg.34_#_99_#_TRINITY_DN242_c0_g1_i4
# NP_015387.1   fgenesh1_kg.7_#_472_#_TRINITY_DN6029_c0_g1_i2
#
#             trichoderma_sinense_daom_230004_v1_0 fusarium_tjaetaba  \
# Orthogroup
# NP_009673.1                       CE149144_25113    XP_037212304.1
# NP_010290.3                            Not found         Not found
# NP_010851.1                         CE43583_1555         Not found
# NP_010893.3                        CE282625_9301    XP_037207718.1
# NP_012965.3                        CE307390_2479    XP_037203345.1
# NP_015387.1                            Not found         Not found
#
#             galerina_marginata_cbs_339_88 neocallimastix_constans_g3_v1_0  \
# Orthogroup
# NP_009673.1                      KDR72580                  e_gw1.13.106.1
# NP_010290.3                     Not found                       Not found
# NP_010851.1                      KDR69137                       Not found
# NP_010893.3                      KDR83643   estExt_Genewise1Plus.C_400096
# NP_012965.3                      KDR79443                       Not found
# NP_015387.1                      KDR73199                       Not found
#
#                         hericium_coralloides_fp_101451_v1_0  \
# Orthogroup
# NP_009673.1                                  CE352478_12376
# NP_010290.3                                       Not found
# NP_010851.1                                       Not found
# NP_010893.3  fgenesh1_kg.19_#_334_#_TRINITY_DN4771_c0_g5_i1
# NP_012965.3                                       Not found
# NP_015387.1                                    CE16674_1415
#
#                          aspergillus_nutans_cbs_121_56_v1_0  \
# Orthogroup
# NP_009673.1  fgenesh1_kg.8_#_608_#_TRINITY_DN11024_c0_g1_i7
# NP_010290.3                                       Not found
# NP_010851.1                                   CE166465_8796
# NP_010893.3                                     CE85965_321
# NP_012965.3   fgenesh1_kg.69_#_19_#_TRINITY_DN9768_c0_g1_i1
# NP_015387.1                                       gm1.281_g
#
#             clitocybe_gibba_ijfm_a808_v1_0 penicillium_egyptiacum  \
# Orthogroup
# NP_009673.1            fgenesh1_pm.31_#_47           CAG8904822.1
# NP_010290.3                      Not found              Not found
# NP_010851.1                      Not found           CAG8907289.1
# NP_010893.3                  e_gw1.2.862.1           CAG8889705.1
# NP_012965.3                  e_gw1.121.4.1           CAG8903919.1
# NP_015387.1                     gm1.2445_g           CAG8893190.1
#
#             monilinia_fructigena_str_mfrg269
# Orthogroup
# NP_009673.1                         RAL64359
# NP_010290.3                        Not found
# NP_010851.1                         RAL64634
# NP_010893.3                         RAL62221
# NP_012965.3                         RAL59412
# NP_015387.1                         RAL66932
#
# [6 rows x 2270 columns]

# %%
ortho_high_identity = ortho_high_identity.reset_index()
ortho_high_identity.to_csv('Orthogroups_HI.tsv', sep='\t', index=False)

# %%
ortho_high_identity['kluyveromyces_marxianus']
# Out:
# 0    XP_022678348.1
# 1    XP_022677214.1
# 2    XP_022673643.1
# 3    XP_022674242.1
# 4    XP_022673914.1
# 5    XP_022678383.1
# Name: kluyveromyces_marxianus, dtype: object
